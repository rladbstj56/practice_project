# %%
import pandas as pd
import numpy as np
import matplotlib
import ast
#matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings('ignore')

# 출력 설정
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

#폰트 설정(없으면 영문으로 나옴)
try:
    font_path = [f for f in fm.findSystemFonts() if 'NanumGothic' in f or 'Malgun' in f or 'AppleGothic' in f]
    if font_path:
        plt.rcParams['font.family'] = fm.FontProperties(fname=font_path[0]).get_name()
    else:
        plt.rcParams['font.family'] = 'DejaVu Sans'
except:
    plt.rcParams['font.family'] = 'DejaVu Sans'

plt.rcParams['axes.unicode_minus'] = False

# %%
funnel = pd.read_csv('./funnel_instance.csv')
analysis = pd.read_csv('./funnel_instance_analysis.csv')

funnel_s = funnel[['customer_id', 'offer_id', 'instance_id', 'gap_to_view', 
            'gap_to_complete', 'gap_view_to_complete', 
            't_received', 't_viewed', 't_completed']
            ]

df = analysis.merge(
    funnel_s,
    on = ['customer_id', 'offer_id', 'instance_id'],
    how='left'
)
df.head(10)
# Out:
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  2906b810c7d4411798c6938adc9daaa5
# 1  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 2  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 3  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 4  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 5  00116118485d4dfda04fdbaba9a87b5c  f19421c1d4aa40978ebb69ca19b0e20d
# 6  00116118485d4dfda04fdbaba9a87b5c  f19421c1d4aa40978ebb69ca19b0e20d
# 7  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 8  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 9  0011e0d4e6b944f998e987f904e8c1e5  3f207df678b143eea3cee63160fa8bed
#
#    t_received_x     offer_type  instance_id  duration  t_expire  t_viewed_x  \
# 0           576       discount            1       7.0     744.0         NaN
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'offer_id', 't_received_x', 'offer_type', 'instance_id',
#        'duration', 't_expire', 't_viewed_x', 'last_viewed', 'view_count',
#        'view_ambiguous', 't_completed_x', 'last_completed', 'complete_count',
#        'comp_ambiguous', 'gap_to_view_x', 'gap_to_complete_x', 'is_viewed',
#        'is_completed', 'completed_without_prior_view',
#        'gap_view_to_complete_x', 'reward', 'difficulty', 'ch_web', 'ch_email',
#        'ch_mobile', 'ch_social', 'channel_count', 'gender', 'age_group',
#        'income_group', 'join_year', 'join_month', 'join_cohort',
#        'gap_to_view_y', 'gap_to_complete_y', 'gap_view_to_complete_y',
#        't_received_y', 't_viewed_y', 't_completed_y'],
#       dtype='str')

# %%
cols_to_check = ['t_received', 't_viewed', 't_completed', 'gap_to_view', 'gap_to_complete', 'gap_view_to_complete']

{col: col in df.columns for col in cols_to_check}
# Out:
# {'t_received': False,
#  't_viewed': False,
#  't_completed': False,
#  'gap_to_view': False,
#  'gap_to_complete': False,
#  'gap_view_to_complete': False}

# %%
df[['gap_to_view', 'gap_to_complete', 'gap_view_to_complete']].describe()
#얼마나 빠르게 보고 / 얼마나 빠르게 행동하며 / 얼마나 빠르게 구매완료하는가
#24 정도에 인지하고 / 61 정도에 행동하며 / 인지 후 구매는 51 정도에 한다
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[['gap_to_view', 'gap_to_complete', 'gap_view_to_complete']].describe()
#       2 #얼마나 빠르게 보고 / 얼마나 빠르게 행동하며 / 얼마나 빠르게 구매완료하는가
#       3 #24 정도에 인지하고 / 61 정도에 행동하며 / 인지 후 구매는 51 정도에 한다
#
# File ~/-/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~/-/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
valid_df = df[
    (df['is_viewed']==True)&
    (df['is_completed']==True)&
    (df['completed_without_prior_view']==False)
].copy()

valid_df.head(10)
# Out:
#                          customer_id                          offer_id  \
# 7   0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 8   0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 11  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 12  0020c2b971eb4e9188eac86d93036a77  4d5c57ea9a6940dd891ad53e9dbe8da0
# 15  0020c2b971eb4e9188eac86d93036a77  fafdcd668e3743c1bb461111dcafc2a4
# 17  0020ccbbb6d84e358d3414a3ff76cffd  2298d6c36e964ae4a3e7e9706d1fb8c2
# 19  0020ccbbb6d84e358d3414a3ff76cffd  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 20  0020ccbbb6d84e358d3414a3ff76cffd  f19421c1d4aa40978ebb69ca19b0e20d
# 24  003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
# 25  003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
#
#     t_received offer_type  instance_id  duration  t_expire  t_viewed  \
# 7          408   discount            1      10.0     648.0     432.0
# ...

# %%
gap_seg = (
    valid_df
    .groupby(['gender', 'age_group', 'income_group'])
    .agg(
        avg_gap = ('gap_view_to_complete', 'mean'),
        median_gap = ('gap_view_to_complete', 'median'),
        n = ('customer_id', 'count')
    )
    .reset_index()
)

gap_seg.sort_values('avg_gap').head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 3
#       1 gap_seg = (
#       2     valid_df
# ----> 3     .groupby(['gender', 'age_group', 'income_group'])
#       4     .agg(
#       5         avg_gap = ('gap_view_to_complete', 'mean'),
#       6         median_gap = ('gap_view_to_complete', 'median'),
#       7         n = ('customer_id', 'count')
#       8     )
#       9     .reset_index()
#      10 )
#      12 gap_seg.sort_values('avg_gap').head(10)
#
# File ~/-/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# ...
